# %%
## text loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader('speech.txt')
loader

# %%
text_documents=loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Good morning everyone,\n\nArtificial Intelligence is transforming the way we live and work.\nIt helps solve real-world problems in healthcare, education, and business.\nHowever, we should use AI responsibly and ethically.\n\nThank you.\n')]

# %%
## pdf file

from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('attention.pdf')
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T18:55:35+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T18:55:35+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'attention.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Attention and Focus\nAttention is the ability to concentrate on a specific task while ignoring distractions. Good attention\nimproves learning, productivity, and decision making.\nWays to improve attention:\n1. Remove distractions.\n2. Take regular breaks.\n3. Sleep well.\n4. Practice mindfulness.')]

# %%
print(len(docs))
print(docs[0].page_content)
# Out:
# 1
# Attention and Focus
# Attention is the ability to concentrate on a specific task while ignoring distractions. Good attention
# improves learning, productivity, and decision making.
# Ways to improve attention:
# 1. Remove distractions.
# 2. Take regular breaks.
# 3. Sleep well.
# 4. Practice mindfulness.

# %%
## web based loader

from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_paths=("https://en.wikipedia.org/wiki/Pok%C3%A9mon",))
loader.load()
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Pok%C3%A9mon', 'title': 'Pokémon - Wikipedia', 'language': 'en'}, page_content='\n\n\n\nPokémon - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload fileSpecial pages\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n\nDonate\n\n\nCreate account\n\n\nLog in\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nName\n\n\n\n\n\n\n\n\n2\nGeneral concept\n\n\n\n\n\n\n\n\n3\nHistory\n\n\n\n\nToggle History subsection\n\n\n\n\n\n3.1\nOrigins\n\n\n\n\n\n\n\n\n3.2\n1989–1995: Development of Red and Green\n\n\n\n\n\n\n\n\n3.3\n1996–1998: Rise in Japan\n\n\n\n\n\n\n3.3.1\nCoroCoro manga, Mew lottery\n\n\n\n\n\n\n\n\n3.3.2\nTrading Card Game\n\n\n\n\n\n\n\n\n3.3.3\nAnime production and premiere\n\n\n\n\n\n\n\n\n3.3.4\n"Dennō Senshi Porygon" incident\n\n\n\n\n\n\n\n\n\n\n3.4\n1998–2000: International expansion\n\n\n\n\n\n\n3.4.1\nNorth America\n\n\n\n\n\n\n\n\n\n\n3.5\n1999–2000: Pokémania\n\n\n\n\n\n\n3.5.1\nThe Pokémon Company and Pokémon USA established\n\n\n\n\n\n\n\n\n\n\n3.6\n2001–2006: End of the craze\n\n\n\n\n\n\n\n\n3.7\n2006–2012: Generation IV–V, TPCi established\n\n\n\n\n\n\n\n\n3.8\n2013–2018: 3D, Generation VI–VII, Pokémon Go\n\n\n\n\n\n\n3.8.1\n2016: Release of Pokémon Go\n\n\n\n\n\n\n\n\n\n\n3.9\n2019–present: Generation VIII–IX, open-world gameplay\n\n\n\n\n\n\n\n\n\n\n4\nMedia\n\n\n\n\nToggle Media subsection\n\n\n\n\n\n4.1\nVideo games\n\n\n\n\n\n\n\n\n4.2\nTrading card game\n\n\n\n\n\n\n\n\n4.3\nAnime\n\n\n\n\n\n\n\n\n4.4\nLive-action\n\n\n\n\n\n\n\n\n\n\n5\nReaction to Pokémania (1999–2000)\n\n\n\n\n\n\n\n\n6\nLegacy and influences\n\n\n\n\n\n\n\n\n7\nFootnotes\n\n\n\n\n\n\n\n\n8\nReferences\n\n\n\n\nToggle References subsection\n\n\n\n\n\n8.1\nMulti-reference notes\n\n\n\n\n\n\n\n\n\n\n9\nExternal links\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\nPokémon\n\n\n\n114 languages\n\n\n\n\nАԥсшәаAfrikaansAlemannischአማርኛالعربيةAsturianuAzərbaycancaБашҡортсаBasa BaliBoarischБеларускаяBetawiБългарскиभोजपुरीবাংলাBrezhonegBosanskiCatalàChavacano de ZamboangaНохчийнCebuanoᏣᎳᎩČeštinaCymraegDanskDeutschZazakiΕλληνικάEsperantoEspañolEestiEuskaraEstremeñuفارسیSuomiFrançaisArpetanFurlanFryskGaeilgeGalegoHawaiʻiעבריתहिन्दीFiji HindiHrvatskiMagyarՀայերենInterlinguaBahasa IndonesiaÍslenskaItalianoᐃᓄᒃᑎᑐᑦ / inuktitut日本語JawaქართულიҚазақша한국어کٲشُرKurdîКыргызчаLatinaLëtzebuergeschLombardLingálaລາວLietuviųLatviešuമലയാളംमराठीКырык марыBahasa MelayuNāhuatlNederlandsNorsk nynorskNorsk bokmålOccitanଓଡ଼ିଆਪੰਜਾਬੀPicardPolskiپنجابیPortuguêsရခိုင်RomânăРусскийСаха тылаScotsSrpskohrvatski / српскохрватскиSimple EnglishSlovenčinaSlovenščinaSoomaaligaShqipСрпски / srpskiSundaSvenskaŚlůnskiதமிழ்ไทยTagalogToki ponaTürkçeУкраїнськаاردوOʻzbekcha / ўзбекчаVènetoTiếng Việt吴语ייִדיש文言閩南語 / Bân-lâm-gí粵語中文\n\nEdit links\n\n\n\n\n\n\n\n\n\n\n\nArticleTalk\n\n\n\n\n\nEnglish\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRead\n\nView source\n\nView history\n\n\n\n\n\n\n\n\n\nTools\n\n\n\n\n\nTools\nmove to sidebar\nhide\n\n\n\n\t\tActions\n\t\n\n\n\nRead\n\n\nView source\n\n\nView history\n\n\n\n\n\n\n\t\tGeneral\n\t\n\n\nWhat links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLSwitch to legacy parser\n\n\n\n\n\n\t\tPrint/export\n\t\n\n\nDownload as PDFPrintable version\n\n\n\n\n\n\t\tIn other projects\n\t\n\n\nWikimedia CommonsWikibooksWikiquoteWikivoyageWikidata item\n\n\n\n\n\n\n\n\n\n\n\n\n ...
